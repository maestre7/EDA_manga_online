# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
palette={"MANGA": "#7986cb", "MANHUA": "#8d6e63", "MANHWA": "#81c784"}
labels = ["MANGA", "MANHWA", "MANHUA"]

# %%
dataset_df = pd.read_csv("../../data/dataset_4.csv", index_col="Unnamed: 0")
print(len(dataset_df))
# Out:
# 19039

# %%
a = dataset_df.columns[15:]
print(len(a))
a
# Out:
# 49
# Index(['Magia', 'Mecha', 'Demonios', 'Género Bender', 'Realidad Virtual',
#        'Drama', 'Niños', 'Guerra', 'Harem', 'Vampiros', 'Horror', 'Acción',
#        'Realidad', 'Traps', 'Militar', 'Crimen', 'Recuentos de la vida',
#        'Apocalíptico', 'Psicológico', 'Misterio', 'Musica', 'Extranjero',
#        'Samurái', 'Girls Love', 'Telenovela', 'Policiaco', 'Animación',
#        'Parodia', 'Deporte', 'Supervivencia', 'Aventura', 'Oeste',
#        'Superpoderes', 'Ecchi', 'Tragedia', 'Fantasia', 'Gore', 'Boys Love',
#        'Reencarnación', 'Sobrenatural', 'Vida Escolar', 'Historia', 'Romance',
#        'Ciencia Ficción', 'Thriller', 'Ciberpunk', 'Artes Marciales',
#        'Comedia', 'Familia'],
#       dtype='object')

# %%
# 5000
drama_df = dataset_df["type"][dataset_df["Drama"]]
recuentos_df = dataset_df["type"][dataset_df["Recuentos de la vida"]]
ecchi_df = dataset_df["type"][dataset_df["Ecchi"]]
aventura_df = dataset_df["type"][dataset_df["Aventura"]]
fantasia_df = dataset_df["type"][dataset_df["Fantasia"]]
boys_love_df = dataset_df["type"][dataset_df["Boys Love"]]
sobrenatural_df = dataset_df["type"][dataset_df["Sobrenatural"]]
vida_escolar_df = dataset_df["type"][dataset_df["Vida Escolar"]]
comedia_df = dataset_df["type"][dataset_df["Comedia"]]
romance_df = dataset_df["type"][dataset_df["Romance"]]

# %%
fig, axes = plt.subplots(2, 5, figsize=(12, 10), sharex="col", sharey="row", )
#fig.delaxes(axes[0,3])
axes[1,0].set_xticklabels(labels, rotation=-45)
axes[1,1].set_xticklabels(labels, rotation=-45)
axes[1,2].set_xticklabels(labels, rotation=-45)
axes[1,3].set_xticklabels(labels, rotation=-45)
axes[1,4].set_xticklabels(labels, rotation=-45)

# Drama
sns.histplot(data=drama_df,
            x=drama_df,
            kde=False,
            hue=drama_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 0]).set(title="Drama", xlabel=None, ylabel=None, ylim=(0, 10000));
# Recuentos de la vida
sns.histplot(data=recuentos_df,
            x=recuentos_df,
            kde=False,
            hue=recuentos_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 1]).set(title="Recuentos de la vida", xlabel=None, ylabel=None, ylim=(0, 10000));
# Ecchi
sns.histplot(data=ecchi_df,
            x=ecchi_df,
            kde=False,
            hue=ecchi_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 2]).set(title="Ecchi", xlabel=None, ylabel=None, ylim=(0, 10000));
# Aventura
sns.histplot(data=aventura_df,
            x=aventura_df,
            kde=False,
            hue=aventura_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 3]).set(title="Aventura", xlabel=None, ylabel=None, ylim=(0, 10000));
# Fantasia
sns.histplot(data=fantasia_df,
            x=fantasia_df,
            kde=False,
            hue=fantasia_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 4]).set(title="Fantasia", xlabel=None, ylabel=None, ylim=(0, 10000));
# Boys Love
sns.histplot(data=boys_love_df,
            x=boys_love_df,
            kde=False,
            hue=boys_love_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 0]).set(title="Boys Love", xlabel=None, ylabel=None, ylim=(0, 10000));

# Sobrenatural
sns.histplot(data=sobrenatural_df,
            x=sobrenatural_df,
            kde=False,
            hue=sobrenatural_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 1]).set(title="Sobrenatural", xlabel=None, ylabel=None, ylim=(0, 10000));
# Vida Escolar
sns.histplot(data=vida_escolar_df,
            x=vida_escolar_df,
            kde=False,
            hue=vida_escolar_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 2]).set(title="Vida Escolar", xlabel=None, ylabel=None, ylim=(0, 10000));
# Comedia
sns.histplot(data=comedia_df,
            x=comedia_df,
            kde=False,
            hue=comedia_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 3]).set(title="Comedia", xlabel=None, ylabel=None, ylim=(0, 10000));
# Romance
sns.histplot(data=romance_df,
            x=romance_df,
            kde=False,
            hue=romance_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 4]).set(title="Romance", xlabel=None, ylabel=None, ylim=(0, 10000));
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\2624276334.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1,0].set_xticklabels(labels, rotation=-45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\2624276334.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1,1].set_xticklabels(labels, rotation=-45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\2624276334.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1,2].set_xticklabels(labels, rotation=-45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\2624276334.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1,3].set_xticklabels(labels, rotation=-45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\2624276334.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1,4].set_xticklabels(labels, rotation=-45)

# %%
fig_histplot = fig
fig_histplot.savefig('../img/by_genre_histplot_part1.png')

# %%
# 1000
reencarnacion_df = dataset_df["type"][dataset_df["Reencarnación"]]
magia_df = dataset_df["type"][dataset_df["Magia"]]
mecha_df = dataset_df["type"][dataset_df["Mecha"]]
demonios_df = dataset_df["type"][dataset_df["Demonios"]]
genero_bender_df = dataset_df["type"][dataset_df["Género Bender"]]
psicologico_df = dataset_df["type"][dataset_df["Psicológico"]]
misterio_df = dataset_df["type"][dataset_df["Misterio"]]
girls_love_df = dataset_df["type"][dataset_df["Girls Love"]]
parodia_df = dataset_df["type"][dataset_df["Parodia"]]
deporte_df = dataset_df["type"][dataset_df["Deporte"]]
supervivencia_df = dataset_df["type"][dataset_df["Supervivencia"]]
superpoderes_df = dataset_df["type"][dataset_df["Superpoderes"]]
gore_df = dataset_df["type"][dataset_df["Gore"]]
tragedia_df = dataset_df["type"][dataset_df["Tragedia"]]
historia_df = dataset_df["type"][dataset_df["Historia"]]
ciencia_ficcion_df = dataset_df["type"][dataset_df["Ciencia Ficción"]]
thriller_df = dataset_df["type"][dataset_df["Thriller"]]
artes_marciales_df = dataset_df["type"][dataset_df["Artes Marciales"]]
familia_df = dataset_df["type"][dataset_df["Familia"]]

# %%
fig, axes = plt.subplots(4, 5, figsize=(12, 10), sharex="col", sharey="row", )
fig.delaxes(axes[3,4])
axes[3,0].set_xticklabels(labels, rotation=-45)
axes[3,1].set_xticklabels(labels, rotation=-45)
axes[3,2].set_xticklabels(labels, rotation=-45)
axes[3,3].set_xticklabels(labels, rotation=-45)
#axes[3,4].set_xticklabels(labels, rotation=-45)

# Reencarnación
sns.histplot(data=reencarnacion_df,
            x=reencarnacion_df,
            kde=False,
            hue=reencarnacion_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 0]).set(title="Reencarnación", xlabel=None, ylabel=None, ylim=(0, 1500));
# Magia
sns.histplot(data=magia_df,
            x=magia_df,
            kde=False,
            hue=magia_df,
            palette=palette,
            alpha=1, 
            legend=False,
            ax=axes[0, 1]).set(title="Magia", xlabel=None, ylabel=None, ylim=(0, 1500)) # ylim=(0, 5000)
# Mecha
sns.histplot(data=mecha_df,
            x=mecha_df,
            kde=False,
            hue=mecha_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 2]).set(title="Mecha", xlabel=None, ylabel=None, ylim=(0, 1500))
# Demonios
sns.histplot(data=demonios_df,
            x=demonios_df,
            kde=False,
            hue=demonios_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 3]).set(title="Demonios", xlabel=None, ylabel=None, ylim=(0, 1500))
# Género Bender
sns.histplot(data=genero_bender_df,
            x=genero_bender_df,
            kde=False,
            hue=genero_bender_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 4]).set(title="Género Bender", xlabel=None, ylabel=None, ylim=(0, 1500));
# Psicológico
sns.histplot(data=psicologico_df,
            x=psicologico_df,
            kde=False,
            hue=psicologico_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 0]).set(title="Psicológico", xlabel=None, ylabel=None, ylim=(0, 1500));
# Misterio
sns.histplot(data=misterio_df,
            x=misterio_df,
            kde=False,
            hue=misterio_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 1]).set(title="Misterio", xlabel=None, ylabel=None, ylim=(0, 1500));
# Girls Love
sns.histplot(data=girls_love_df,
            x=girls_love_df,
            kde=False,
            hue=girls_love_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 2]).set(title="Girls Love", xlabel=None, ylabel=None, ylim=(0, 1500));
# Parodia
sns.histplot(data=parodia_df,
            x=parodia_df,
            kde=False,
            hue=parodia_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 3]).set(title="Parodia", xlabel=None, ylabel=None, ylim=(0, 1500));
# Deporte
sns.histplot(data=deporte_df,
            x=deporte_df,
            kde=False,
            hue=deporte_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 4]).set(title="Deporte", xlabel=None, ylabel=None, ylim=(0, 1500));
# Supervivencia
sns.histplot(data=supervivencia_df,
            x=supervivencia_df,
            kde=False,
            hue=supervivencia_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[2, 0]).set(title="Supervivencia", xlabel=None, ylabel=None, ylim=(0, 1500));
# Superpoderes
sns.histplot(data=superpoderes_df,
            x=superpoderes_df,
            kde=False,
            hue=superpoderes_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[2, 1]).set(title="Superpoderes", xlabel=None, ylabel=None, ylim=(0, 1500));
# Gore
sns.histplot(data=gore_df,
            x=gore_df,
            kde=False,
            hue=gore_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[2, 2]).set(title="Gore", xlabel=None, ylabel=None, ylim=(0, 1500));
# Tragedia
sns.histplot(data=tragedia_df,
            x=tragedia_df,
            kde=False,
            hue=tragedia_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[2, 3]).set(title="Tragedia", xlabel=None, ylabel=None, ylim=(0, 1500));
# Historia
sns.histplot(data=historia_df,
            x=historia_df,
            kde=False,
            hue=historia_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[2, 4]).set(title="Historia", xlabel=None, ylabel=None, ylim=(0, 1500));
# Ciencia Ficción
sns.histplot(data=ciencia_ficcion_df,
            x=ciencia_ficcion_df,
            kde=False,
            hue=ciencia_ficcion_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[3, 0]).set(title="Ciencia Ficción", xlabel=None, ylabel=None, ylim=(0, 1500));
# Thriller
sns.histplot(data=thriller_df,
            x=thriller_df,
            kde=False,
            hue=thriller_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[3, 1]).set(title="Thriller", xlabel=None, ylabel=None, ylim=(0, 1500));
# Artes Marciales
sns.histplot(data=artes_marciales_df,
            x=artes_marciales_df,
            kde=False,
            hue=artes_marciales_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[3, 2]).set(title="Artes Marciales", xlabel=None, ylabel=None, ylim=(0, 1500));
# Familia
sns.histplot(data=familia_df,
            x=familia_df,
            kde=False,
            hue=familia_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[3, 3]).set(title="Familia", xlabel=None, ylabel=None, ylim=(0, 1500));
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\2472119711.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[3,0].set_xticklabels(labels, rotation=-45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\2472119711.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[3,1].set_xticklabels(labels, rotation=-45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\2472119711.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[3,2].set_xticklabels(labels, rotation=-45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\2472119711.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[3,3].set_xticklabels(labels, rotation=-45)

# %%
fig_histplot = fig
fig_histplot.savefig('../img/by_genre_histplot_part2.png')

# %%
# 100
realidad_virtual_df = dataset_df["type"][dataset_df["Realidad Virtual"]]
ninos_df = dataset_df["type"][dataset_df["Niños"]]
traps_df = dataset_df["type"][dataset_df["Traps"]]
militar_df = dataset_df["type"][dataset_df["Militar"]]
crimen_df = dataset_df["type"][dataset_df["Crimen"]]
apocaliptico_df = dataset_df["type"][dataset_df["Apocalíptico"]]
musica_df = dataset_df["type"][dataset_df["Musica"]]
extranjero_df = dataset_df["type"][dataset_df["Extranjero"]]
samurai_df = dataset_df["type"][dataset_df["Samurái"]]
telenovela_df = dataset_df["type"][dataset_df["Telenovela"]]
policiaco_df = dataset_df["type"][dataset_df["Policiaco"]]
animacion_df = dataset_df["type"][dataset_df["Animación"]]
oeste_df = dataset_df["type"][dataset_df["Oeste"]]
ciberpunk_df = dataset_df["type"][dataset_df["Ciberpunk"]]

# %%
fig, axes = plt.subplots(3, 5, figsize=(12, 10), sharex="col", sharey="row", )
fig.delaxes(axes[2,4])
axes[2,0].set_xticklabels(labels, rotation=-45)
axes[2,1].set_xticklabels(labels, rotation=-45)
axes[2,2].set_xticklabels(labels, rotation=-45)
axes[2,3].set_xticklabels(labels, rotation=-45)

# Realidad Virtual
sns.histplot(data=realidad_virtual_df,
            x=realidad_virtual_df,
            kde=False,
            hue=realidad_virtual_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 0]).set(title="Realidad Virtual", xlabel=None, ylabel=None, ylim=(0, 150));
# Niños
sns.histplot(data=ninos_df,
            x=ninos_df,
            kde=False,
            hue=ninos_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 1]).set(title="Niños", xlabel=None, ylabel=None, ylim=(0, 150));
# Traps
sns.histplot(data=traps_df,
            x=traps_df,
            kde=False,
            hue=traps_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 2]).set(title="Traps", xlabel=None, ylabel=None, ylim=(0, 150));
# Militar
sns.histplot(data=militar_df,
            x=militar_df,
            kde=False,
            hue=militar_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 3]).set(title="Militar", xlabel=None, ylabel=None, ylim=(0, 150));
# Crimen
sns.histplot(data=crimen_df,
            x=crimen_df,
            kde=False,
            hue=crimen_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[0, 4]).set(title="Crimen", xlabel=None, ylabel=None, ylim=(0, 150));
# Apocalíptico
sns.histplot(data=apocaliptico_df,
            x=apocaliptico_df,
            kde=False,
            hue=apocaliptico_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 0]).set(title="Apocalíptico", xlabel=None, ylabel=None, ylim=(0, 150));
# Musica
sns.histplot(data=musica_df,
            x=musica_df,
            kde=False,
            hue=musica_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 1]).set(title="Musica", xlabel=None, ylabel=None, ylim=(0, 150));
# Extranjero
sns.histplot(data=extranjero_df,
            x=extranjero_df,
            kde=False,
            hue=extranjero_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 2]).set(title="Extranjero", xlabel=None, ylabel=None, ylim=(0, 150));
# Samurái
sns.histplot(data=samurai_df,
            x=samurai_df,
            kde=False,
            hue=samurai_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 3]).set(title="Samurái", xlabel=None, ylabel=None, ylim=(0, 150));
# Telenovela
sns.histplot(data=telenovela_df,
            x=telenovela_df,
            kde=False,
            hue=telenovela_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[1, 4]).set(title="Telenovela", xlabel=None, ylabel=None, ylim=(0, 150));
# Policiaco
sns.histplot(data=policiaco_df,
            x=policiaco_df,
            kde=False,
            hue=policiaco_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[2, 0]).set(title="Policiaco", xlabel=None, ylabel=None, ylim=(0, 150));
# Animación
sns.histplot(data=animacion_df,
            x=animacion_df,
            kde=False,
            hue=animacion_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[2, 1]).set(title="Animación", xlabel=None, ylabel=None, ylim=(0, 150));
# Oeste
sns.histplot(data=oeste_df,
            x=oeste_df,
            kde=False,
            hue=oeste_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[2, 2]).set(title="Oeste", xlabel=None, ylabel=None, ylim=(0, 150));
# Ciberpunk
sns.histplot(data=ciberpunk_df,
            x=ciberpunk_df,
            kde=False,
            hue=ciberpunk_df,
            palette=palette,
            alpha=1,
            legend=False,
            ax=axes[2, 3]).set(title="Ciberpunk", xlabel=None, ylabel=None, ylim=(0, 150));
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\4034744932.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[2,0].set_xticklabels(labels, rotation=-45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\4034744932.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[2,1].set_xticklabels(labels, rotation=-45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\4034744932.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[2,2].set_xticklabels(labels, rotation=-45)
# C:\Users\usuario\AppData\Local\Temp\ipykernel_1104\4034744932.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[2,3].set_xticklabels(labels, rotation=-45)

# %%
fig_histplot = fig
fig_histplot.savefig('../img/by_genre_histplot_part3.png')
